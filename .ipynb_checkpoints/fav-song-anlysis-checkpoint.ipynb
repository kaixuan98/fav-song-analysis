# %%
import pandas as pd
import matplotlib.pyplot as plt
import get_data as data_call

import matplotlib
matplotlib.font_manager._rebuild()

# %% [markdown]
# ### Data Cleaning
# From the `get_data.py`, we are able to get the liked song and output into a csv. We have a list a favorite song with its respective ids and artists.
# <br>
# In this section, we are getting the audio features from spotify through spotipy to do our song analysis
# <br>
# In this data, we only taking first 250 songs and index 0 as the recently added

# %%
fav_song_list = pd.read_csv('fav_song_list.csv')
fav_song_list.head()
# Out:
#                                            song_name                 song_id  \
# 0     If the World Was Ending - feat. Julia Michaels  2kJwzbxV2ppxnQoYw4GLBZ
# 1  刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...  3OC84eKMxRJ4x0Hcwl9i4i
# 2                                             流著淚說分手  7LMPRmLVC5seyuf5n6gKZi
# 3                                             阿拉斯加海湾  5DCNAwyomUF3LXunq4NSpJ
# 4                                               飞鸟和蝉  3IveWAHTMxZA4KYBPnylq5
#
#       artist_name               artist_id  popularity
# 0         JP Saxe  66W9LaWS0DPdL7Sz8iYGYe          85
# 1        Crowd Lu  2JBUyLiFvpFPWdZGqIGYLD          72
# 2              小文  1klqNQAhhI5d4P5WWpBIEe          20
# 3  Priscilla Abby  0zFBdI3ErhNDcIPAKiGoL0          57
# 4         Ren Ran  6f4srX54JFrLNK4aTJe2Sc          51

# %%
# authentication, one of the function that I have wrote in get_data_py
sp = data_call.create_user_auth()

# %%
#requesting audio features from Spotify
audio_feature_sample=sp.audio_features(fav_song_list['song_id'][2])
print(audio_feature_sample)
# Out:
# [{'danceability': 0.65, 'energy': 0.148, 'key': 10, 'loudness': -13.396, 'mode': 0, 'speechiness': 0.0396, 'acousticness': 0.912, 'instrumentalness': 0, 'liveness': 0.119, 'valence': 0.276, 'tempo': 77.936, 'type': 'audio_features', 'id': '7LMPRmLVC5seyuf5n6gKZi', 'uri': 'spotify:track:7LMPRmLVC5seyuf5n6gKZi', 'track_href': 'https://api.spotify.com/v1/tracks/7LMPRmLVC5seyuf5n6gKZi', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LMPRmLVC5seyuf5n6gKZi', 'duration_ms': 250093, 'time_signature': 4}]

# %%
# creating a list of audio features(appending each dictionary into the list)
list_of_audio_features=[]
for index, row in fav_song_list.iterrows():
    audio_features= sp.audio_features(row["song_id"])
    list_of_audio_features.append(audio_features[0])

# %%
#creating a data frame of audio features with the list 
audio_features_list=pd.DataFrame(list_of_audio_features)

# %%
# renaming id to song_id to allow overlapping
audio_features_list=audio_features_list.rename(columns={"id" : "song_id"})

# %%
# join the overlap which is song_id
df = audio_features_list.combine_first(fav_song_list)

#getting the list of the columns
cols = df.columns.tolist()

#reordering the columns and our final dataset has been set into df
df = df[['song_name','song_id','artist_id','artist_name','popularity','acousticness','danceability','energy','instrumentalness','key',
         'liveness','loudness','mode','speechiness','tempo','valence','time_signature','duration_ms',
         'track_href','type','uri','analysis_url']]
df
# Out:
#                                              song_name  \
# 0       If the World Was Ending - feat. Julia Michaels
# 1    刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 2                                               流著淚說分手
# 3                                               阿拉斯加海湾
# 4                                                 飞鸟和蝉
# ..                                                 ...
# 245                               When Will I Be Loved
# 246                                              Mercy
# 247        Don't Rain On My Parade (Glee Cast Version)
# 248    My Favourite Things (From "The Sound of Music")
# 249               Bon Bon Bon (as featured in Killers)
#
#                     song_id               artist_id  \
# 0    2kJwzbxV2ppxnQoYw4GLBZ  66W9LaWS0DPdL7Sz8iYGYe
# 1    3OC84eKMxRJ4x0Hcwl9i4i  2JBUyLiFvpFPWdZGqIGYLD
# 2    7LMPRmLVC5seyuf5n6gKZi  1klqNQAhhI5d4P5WWpBIEe
# 3    5DCNAwyomUF3LXunq4NSpJ  0zFBdI3ErhNDcIPAKiGoL0
# 4    3IveWAHTMxZA4KYBPnylq5  6f4srX54JFrLNK4aTJe2Sc
# ..                      ...                     ...
# 245  0rOFRZ39bdoLADXcb5UZus  4ACplpEqD6JIVgKrafauzs
# 246  1dKm4a7TOYFzzTQvU59C59  37NqXwtb6nIEqRt4EJSoIO
# 247  7emV91bLzV662TpX9Tmxnr  0SCbttzoZTnLFebDYmAWCm
# 248  51JrbFRTiIZqJFNRj2rNAG  2oQJQUIpJFFnfKvHJA0xBu
# 249  5KqIoZTT3XzxikEgQ14gNy  3LYXc3LZf9PCYDrLMY0Qy0
#
#                                    artist_name  popularity  acousticness  \
# 0                                      JP Saxe        85.0        0.8660
# 1                                     Crowd Lu        72.0        0.8730
# 2                                           小文        20.0        0.9120
# 3                               Priscilla Abby        57.0        0.7380
# 4                                      Ren Ran        51.0        0.7490
# ..                                         ...         ...           ...
# 245                        The Everly Brothers         0.0        0.1560
# 246                                      Duffy         0.0        0.2660
# 247                                  Glee Cast        57.0        0.5980
# 248  The City of Prague Philharmonic Orchestra        11.0        0.9340
# 249                  Vanessa Contenay-Quinones        10.0        0.0279
#
#      danceability  energy  instrumentalness  key  ...  mode  speechiness  \
# 0           0.464   0.473          0.000000    1  ...     1       0.1290
# 1           0.425   0.201          0.000000   10  ...     1       0.0373
# 2           0.650   0.148          0.000000   10  ...     0       0.0396
# 3           0.630   0.309          0.000000   10  ...     1       0.0350
# 4           0.569   0.567          0.000000   10  ...     1       0.0527
# ..            ...     ...               ...  ...  ...   ...          ...
# 245         0.597   0.487          0.000000   11  ...     1       0.0336
# 246         0.793   0.859          0.000356    0  ...     1       0.0332
# 247         0.483   0.691          0.000000    4  ...     1       0.0805
# 248         0.577   0.224          0.000035    4  ...     0       0.0504
# 249         0.740   0.902          0.000000    4  ...     1       0.0485
#
#        tempo  valence  time_signature  duration_ms  \
# 0     75.801    0.604               4       208687
# 1    136.328    0.267               4       320166
# 2     77.936    0.276               4       250093
# 3    117.814    0.155               4       237841
# 4    147.962    0.321               4       296031
# ..       ...      ...             ...          ...
# 245  118.104    0.711               4       115310
# 246  129.912    0.964               4       219920
# 247   79.666    0.597               4       165493
# 248   98.103    0.579               3       124533
# 249  120.042    0.726               4       213023
#
#                                             track_href            type  \
# 0    https://api.spotify.com/v1/tracks/2kJwzbxV2ppx...  audio_features
# 1    https://api.spotify.com/v1/tracks/3OC84eKMxRJ4...  audio_features
# 2    https://api.spotify.com/v1/tracks/7LMPRmLVC5se...  audio_features
# 3    https://api.spotify.com/v1/tracks/5DCNAwyomUF3...  audio_features
# 4    https://api.spotify.com/v1/tracks/3IveWAHTMxZA...  audio_features
# ..                                                 ...             ...
# 245  https://api.spotify.com/v1/tracks/0rOFRZ39bdoL...  audio_features
# 246  https://api.spotify.com/v1/tracks/1dKm4a7TOYFz...  audio_features
# 247  https://api.spotify.com/v1/tracks/7emV91bLzV66...  audio_features
# 248  https://api.spotify.com/v1/tracks/51JrbFRTiIZq...  audio_features
# 249  https://api.spotify.com/v1/tracks/5KqIoZTT3Xzx...  audio_features
#
#                                       uri  \
# 0    spotify:track:2kJwzbxV2ppxnQoYw4GLBZ
# 1    spotify:track:3OC84eKMxRJ4x0Hcwl9i4i
# 2    spotify:track:7LMPRmLVC5seyuf5n6gKZi
# 3    spotify:track:5DCNAwyomUF3LXunq4NSpJ
# 4    spotify:track:3IveWAHTMxZA4KYBPnylq5
# ..                                    ...
# 245  spotify:track:0rOFRZ39bdoLADXcb5UZus
# 246  spotify:track:1dKm4a7TOYFzzTQvU59C59
# 247  spotify:track:7emV91bLzV662TpX9Tmxnr
# 248  spotify:track:51JrbFRTiIZqJFNRj2rNAG
# 249  spotify:track:5KqIoZTT3XzxikEgQ14gNy
#
#                                           analysis_url
# 0    https://api.spotify.com/v1/audio-analysis/2kJw...
# 1    https://api.spotify.com/v1/audio-analysis/3OC8...
# 2    https://api.spotify.com/v1/audio-analysis/7LMP...
# 3    https://api.spotify.com/v1/audio-analysis/5DCN...
# 4    https://api.spotify.com/v1/audio-analysis/3Ive...
# ..                                                 ...
# 245  https://api.spotify.com/v1/audio-analysis/0rOF...
# 246  https://api.spotify.com/v1/audio-analysis/1dKm...
# 247  https://api.spotify.com/v1/audio-analysis/7emV...
# 248  https://api.spotify.com/v1/audio-analysis/51Jr...
# 249  https://api.spotify.com/v1/audio-analysis/5KqI...
#
# [250 rows x 22 columns]

# %%
#dropping the columns that we do not need
df=df.drop(columns=['track_href','type','analysis_url'])
df
# Out:
#                                              song_name  \
# 0       If the World Was Ending - feat. Julia Michaels
# 1    刻在我心底的名字 (Your Name Engraved Herein) - 電影<刻在你心...
# 2                                               流著淚說分手
# 3                                               阿拉斯加海湾
# 4                                                 飞鸟和蝉
# ..                                                 ...
# 245                               When Will I Be Loved
# 246                                              Mercy
# 247        Don't Rain On My Parade (Glee Cast Version)
# 248    My Favourite Things (From "The Sound of Music")
# 249               Bon Bon Bon (as featured in Killers)
#
#                     song_id               artist_id  \
# 0    2kJwzbxV2ppxnQoYw4GLBZ  66W9LaWS0DPdL7Sz8iYGYe
# 1    3OC84eKMxRJ4x0Hcwl9i4i  2JBUyLiFvpFPWdZGqIGYLD
# 247  spotify:track:7emV91bLzV662TpX9Tmxnr
# 248  spotify:track:51JrbFRTiIZqJFNRj2rNAG
# 249  spotify:track:5KqIoZTT3XzxikEgQ14gNy
#
# [250 rows x 19 columns]

# %% [markdown]
# ### Data Analysis
# We had got the data that we need from Spotify and all the audio features are now in a data frame, we are ready to do our song analysis.
#
# Before ploting any graph, we need to understand our dataset.
# ##### Understanding our Dataset
# * basic identifier of the song which is the song name with its id and the artist(s) that is(are) performing
# * `acousticness` = measurement of the acoustic feature of the song , 1 being high probability of acoustic
# * `danceability` = measurement of the suitability for a dance
# * `energy` = measurement of intensity
# * `instrumentalness` = measurement it likelihood of being an instrumental song (no vocal content)
# * `key` = pitches of the song (C= 0, C#/Db=1...) (12 notes in an octave)
# * `liveness` = detect the presence of live audience
# * `loudness` = how loud of the song in decibles (dB)
# * `mode` = major or minor
# * `speechiness` = detect the spoken words in a track
# * `tempo` = bpm of the track
# * `valence` = mood of the song
# * `time_signature` = the number of beats in each bar
# * `duration_ms` = how long of the song in miliseconds
# * `popularity` = how popular of the song based on the number of plays on that song and how recent is that play
# For more clearer information check the spotify api : https://developer.spotify.com/documentation/web-api/reference/#object-audiofeaturesobject

# %% [markdown]
# I always think that I listen to some slow and mellow music. We can start by plotting the average tempo the list

# %%
# getting the average tempo of all songs 
avg_tempo = df["tempo"].mean()
print("Average Tempo: " + str(avg_tempo))
max_tempo = df["tempo"].max()
print("Max Tempo: " + str(max_tempo))
min_tempo = df["tempo"].min()
print("Min Tempo: "+ str(min_tempo))
max_index = df["tempo"].idxmax()
max_tempo_track = df.iloc[max_index]
print("Track with max tempo: " + max_tempo_track["song_name"])
min_index = df["tempo"].idxmin()
min_tempo_track= df.iloc[min_index]
print("Track with min tempo: " + min_tempo_track["song_name"])
# Out:
# Average Tempo: 118.735636
# Max Tempo: 201.294
# Min Tempo: 68.534
# Track with max tempo: 從開始到現在 (電視劇《冬季戀歌》正宗主題曲中文版)
# Track with min tempo: Lover

# %%
split_to_five = pd.cut(df["tempo"],bins=5)
ax = split_to_five.value_counts(sort=False).plot.bar(rot=0, color="b", figsize=(6,4))
plt.xticks(rotation = 45)
plt.xlabel("tempo(bpm)")
plt.ylabel("frequency")
plt.title("The frequency for each tempo groups")
plt.show()

# %% [markdown]
# Tempo is calculated with beats per min (bpm), where beat is a reason that why we clap or stump our feet while listen to a track.
# <br>
# Most of my songs in the range of 95bpm to 150bpm.
# <br>
# We can also look at the valence of each song in my list.

# %%
avg_valence = df["valence"].mean()
print("Average Valence: " + str(avg_valence))
max_valence = df["valence"].max()
print("Max Valence: " + str(max_valence))
min_valence = df["valence"].min()
print("Min Valence: "+ str(min_valence))
max_index = df["valence"].idxmax()
max_valence_track = df.iloc[max_index]
print("Track with max valence: " + max_valence_track["song_name"])
min_index = df["valence"].idxmin()
min_valence_track= df.iloc[min_index]
print("Track with min valence: " + min_valence_track["song_name"])
# Out:
# Average Valence: 0.42338400000000004
# Max Valence: 0.991
# Min Valence: 0.0598
# Track with max valence: 愛的初體驗
# Track with min valence: Down

# %%
def get_basic_stats(data_series):
    result = []
    avg = df[data_series].mean()
    result.append({"Avg":avg})
    maximum = df[data_series].max()
    result.append({"max":maximum})
    minimum = df[data_series].min()
    result.append({"min":minimum})
    max_index = df[data_series].idxmax()
    max_track = df.iloc[max_index]
    max_track = max_track["song_name"]
    result.append({"Max Track":max_track})
    min_index = df[data_series].idxmin()
    min_track = df.iloc[min_index]
    min_track = min_track["song_name"]
    result.append({"Min Track":min_track})
    return result

# %%
get_basic_stats("danceability")
# Out:
# [{'Avg': 0.5843039999999999},
#  {'max': 0.908},
#  {'min': 0.119},
#  {'Max Track': 'Hope'},
#  {'Min Track': 'Game of Thrones Medley'}]

# %%
get_basic_stats("energy")
# Out:
# [{'Avg': 0.5654527999999999},
#  {'max': 0.972},
#  {'min': 0.026},
#  {'Max Track': '我的果汁分你一半'},
#  {'Min Track': 'Moon River'}]

# %%
get_basic_stats("acousticness")
# Out:
# [{'Avg': 0.4056840104},
#  {'max': 0.995},
#  {'min': 6.56e-05},
#  {'Max Track': 'Moon River'},
#  {'Min Track': 'Butter-Fly'}]

# %%
mean_of_data = df.mean(axis=0)
mean_of_data
# Out:
# popularity              43.656000
# acousticness             0.405684
# danceability             0.584304
# energy                   0.565453
# instrumentalness         0.008832
# key                      5.284000
# liveness                 0.173164
# loudness                -7.184384
# mode                     0.736000
# speechiness              0.061664
# tempo                  118.735636
# valence                  0.423384
# time_signature           3.924000
# duration_ms         234307.532000
# dtype: float64

# %%
mean_of_audio_features= mean_of_data.drop(["popularity","key","loudness","mode","tempo","time_signature","duration_ms"])

# %%
histogram= mean_of_audio_features.plot.bar(color="b", figsize=(6,4))
plt.xticks(rotation = 90)
plt.xlabel("audio features")
plt.ylabel("mean")
plt.title("Mean of each features")
plt.show()

# %%
# find the correlationship between data 
corr_matrix = df.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col0,#T_328ba34e_a216_11eb_8043_34363bcdac9crow1_col1,#T_328ba34e_a216_11eb_8043_34363bcdac9crow2_col2,#T_328ba34e_a216_11eb_8043_34363bcdac9crow3_col3,#T_328ba34e_a216_11eb_8043_34363bcdac9crow4_col4,#T_328ba34e_a216_11eb_8043_34363bcdac9crow5_col5,#T_328ba34e_a216_11eb_8043_34363bcdac9crow6_col6,#T_328ba34e_a216_11eb_8043_34363bcdac9crow7_col7,#T_328ba34e_a216_11eb_8043_34363bcdac9crow8_col8,#T_328ba34e_a216_11eb_8043_34363bcdac9crow9_col9,#T_328ba34e_a216_11eb_8043_34363bcdac9crow10_col10,#T_328ba34e_a216_11eb_8043_34363bcdac9crow11_col11,#T_328ba34e_a216_11eb_8043_34363bcdac9crow12_col12,#T_328ba34e_a216_11eb_8043_34363bcdac9crow13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col1{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col2{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col3,#T_328ba34e_a216_11eb_8043_34363bcdac9crow3_col12,#T_328ba34e_a216_11eb_8043_34363bcdac9crow10_col1{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col4{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col5,#T_328ba34e_a216_11eb_8043_34363bcdac9crow2_col1,#T_328ba34e_a216_11eb_8043_34363bcdac9crow10_col9,#T_328ba34e_a216_11eb_8043_34363bcdac9crow12_col8{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col6,#T_328ba34e_a216_11eb_8043_34363bcdac9crow3_col8{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col7{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col8,#T_328ba34e_a216_11eb_8043_34363bcdac9crow8_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_col9,#T_328ba34e_a216_11eb_8043_34363bcdac9crow7_col10,#T_328ba34e_a216_11eb_8043_34363bcdac9crow12_col13,#T_328ba34e_a216_11eb_8043_34363bcdac9crow13_col4{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_328ba34e_a216_11eb_8043_34363bcdac9crow0_